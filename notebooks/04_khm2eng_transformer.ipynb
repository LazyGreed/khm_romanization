# %% [markdown]
# # Khmer to English using seq2seq transformer

# %%
import os
import numpy as np
import pandas as pd
import pickle
import re
import unicodedata
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Embedding, Dense, LayerNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
# Out:
# 2025-12-14 07:50:48.825432: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-14 07:50:48.893494: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-14 07:50:50.176469: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-14 07:50:50.176469: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# config
EMBED_DIM = 128
LATENT_DIM = 256
NUM_HEADS = 4
BATCH_SIZE = 64
EPOCHS = 50

BASE_DIR = os.path.dirname(os.path.abspath('.'))
DATA_PATH = os.path.join(BASE_DIR, "data", "raw", "eng_khm_data.csv")
MODEL_PATH = os.path.join(BASE_DIR, "models", "transformer_romanizer.keras")
ASSETS_PATH = os.path.join(BASE_DIR, "data", "processed", "transformer_romanization_assets.pkl")
RESULTS_PATH = os.path.join(BASE_DIR, "results")

os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)
os.makedirs(os.path.dirname(ASSETS_PATH), exist_ok=True)
os.makedirs(RESULTS_PATH, exist_ok=True)

# %%
# load and preprocess data
df = pd.read_csv(DATA_PATH)
dataset = []

for _, row in df.iterrows():
    normalized_khm = re.sub(r"[^\u1780-\u17FF]", "", row['khm'])
    normalized_khm = unicodedata.normalize('NFC', normalized_khm)
    
    normalized_eng = re.sub(r"[^a-z]", "", row['eng'].lower())

    dataset.append((normalized_khm, normalized_eng))

print(f"Dataset size: {len(dataset)}")
print("Sample pairs:", dataset[:3])
# Out:
# Dataset size: 28576
# Sample pairs: [('ប្រដែ', 'brodae'), ('អសង្ខៃយ', 'aasangkheyy'), ('ឆាតកភ័យ', 'chhatkophey')]

# %%
# tokenize
khm_tokenizer = Tokenizer(char_level=True, filters='', oov_token='<unk>')
khm_tokenizer.fit_on_texts([pair[0] for pair in dataset])

eng_tokenizer = Tokenizer(char_level=True, filters='', oov_token='<unk>')
eng_tokenizer.fit_on_texts(["\t", "\n"] + [pair[1] for pair in dataset])

print(f"Khmer vocab size: {len(khm_tokenizer.word_index) + 1}")
print(f"English vocab size: {len(eng_tokenizer.word_index) + 1}")
# Out:
# Khmer vocab size: 79
# English vocab size: 30

# %%
# verify special tokens are in the tokenizer
print("Checking special tokens in eng_tokenizer:")
print(f"'\\t' token index: {eng_tokenizer.word_index.get('\\t', 'NOT FOUND')}")
print(f"'\\n' token index: {eng_tokenizer.word_index.get('\\n', 'NOT FOUND')}")
print(f"\ntokens in eng_tokenizer: {list(eng_tokenizer.word_index.items())}")
print(f"\ntokens in khm_tokenizer: {list(khm_tokenizer.word_index.items())}")
# Out:
# Checking special tokens in eng_tokenizer:
# '\t' token index: NOT FOUND
# '\n' token index: NOT FOUND
#
# tokens in eng_tokenizer: [('<unk>', 1), ('a', 2), ('o', 3), ('h', 4), ('e', 5), ('n', 6), ('r', 7), ('k', 8), ('t', 9), ('u', 10), ('s', 11), ('m', 12), ('b', 13), ('i', 14), ('c', 15), ('p', 16), ('l', 17), ('g', 18), ('y', 19), ('v', 20), ('d', 21), ('j', 22), ('z', 23), ('f', 24), ('w', 25), ('x', 26), ('q', 27), ('\t', 28), ('\n', 29)]
#
# tokens in khm_tokenizer: [('<unk>', 1), ('្', 2), ('ា', 3), ('រ', 4), ('ក', 5), ('ស', 6), ('ប', 7), ('ត', 8), ('ន', 9), ('ម', 10), ('ង', 11), ('ិ', 12), ('ល', 13), ('អ', 14), ('ច', 15), ('ុ', 16), ('វ', 17), ('ទ', 18), ('យ', 19), ('់', 20), ('ព', 21), ('ំ', 22), ('ហ', 23), ('ោ', 24), ('ជ', 25), ('េ', 26), ('គ', 27), ('ី', 28), ('ណ', 29), ('ញ', 30), ('ដ', 31), ('ូ', 32), ('ភ', 33), ('ែ', 34), ('ធ', 35), ('ខ', 36), ('ើ', 37), ('៉', 38), ('ះ', 39), ('ឹ', 40), ('ួ', 41), ('ឡ', 42), ('ថ', 43), ('ផ', 44), ('ៀ', 45), ('័', 46), ('ៈ', 47), ('ឆ', 48), ('៍', 49), ('ៃ', 50), ('៊', 51), ('ឋ', 52), ('ឺ', 53), ('ៗ', 54), ('ឌ', 55), ('ឧ', 56), ('ៅ', 57), ('ឃ', 58), ('ឈ', 59), ('៌', 60), ('ឿ', 61), ('ឥ', 62), ('ឱ', 63), ('ឫ', 64), ('ឯ', 65), ('ឍ', 66), ('៎', 67), ('៏', 68), ('ឪ', 69), ('ឩ', 70), ('ឲ', 71), ('ឦ', 72), ('ឮ', 73), ('ឰ', 74), ('ឳ', 75), ('។', 76), ('ឭ', 77), ('ឬ', 78)]

# %%
# create sequences
encoder_inputs, decoder_inputs, decoder_targets = [], [], []
max_khm_len = max(len(pair[0]) for pair in dataset) or 1
max_eng_len = max(len(pair[1]) for pair in dataset) or 1

for khm, eng in dataset:
    # encoder sequence (khmer)
    khm_seq = khm_tokenizer.texts_to_sequences([khm])[0]
    encoder_inputs.append(khm_seq)

    # decoder sequences (english)
    eng_seq = eng_tokenizer.texts_to_sequences([eng])[0]
    decoder_input = [eng_tokenizer.word_index['\t']] + eng_seq
    decoder_target = eng_seq + [eng_tokenizer.word_index['\n']]
    
    decoder_inputs.append(decoder_input)
    decoder_targets.append(decoder_target)

X_train_full = pad_sequences(encoder_inputs, maxlen=max_khm_len, padding='post')
decoder_input_data_full = pad_sequences(decoder_inputs, maxlen=max_eng_len + 1, padding='post')
decoder_target_data_full = pad_sequences(decoder_targets, maxlen=max_eng_len + 1, padding='post')

# Train/test split
X_train, X_test, dec_in_train, dec_in_test, dec_tgt_train, dec_tgt_test = train_test_split(
    X_train_full, decoder_input_data_full, decoder_target_data_full, 
    test_size=0.2, random_state=42
)

num_encoder_tokens = len(khm_tokenizer.word_index) + 1
num_decoder_tokens = len(eng_tokenizer.word_index) + 1

print(f"Training samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")
print(f"Max Khmer length: {max_khm_len}")
print(f"Max English length: {max_eng_len}")
# Out:
# Training samples: 22860
# Test samples: 5716
# Max Khmer length: 24
# Max English length: 25

# %%
# build transformer model
# Encoder
encoder_inputs = Input(shape=(None,), name='encoder_inputs')
enc_emb = Embedding(input_dim=num_encoder_tokens, output_dim=EMBED_DIM)(encoder_inputs)
encoder_dense = Dense(LATENT_DIM, activation='relu')(enc_emb)

# Decoder
decoder_inputs = Input(shape=(None,), name='decoder_inputs')
dec_emb = Embedding(input_dim=num_decoder_tokens, output_dim=EMBED_DIM)(decoder_inputs)
decoder_dense_input = Dense(LATENT_DIM, activation='relu')(dec_emb)

# Multi-head attention (encoder->decoder)
attention_output = tf.keras.layers.MultiHeadAttention(
    num_heads=NUM_HEADS, key_dim=LATENT_DIM
)(decoder_dense_input, encoder_dense)
attention_output = LayerNormalization()(attention_output + decoder_dense_input)
dropout_output = Dropout(0.2)(attention_output)

# Output layer
decoder_outputs = Dense(num_decoder_tokens, activation='softmax')(dropout_output)

# Build and compile model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs, name='transformer_seq2seq')
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765698653.378380   98924 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 703 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# Model: "transformer_seq2seq"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ decoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 128) │      3,840 │ decoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, None, 128) │     10,112 │ encoder_inputs[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 256) │     33,024 │ embedding_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None, 256) │     33,024 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, None, 256) │  1,051,904 │ dense_1[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, None, 256) │          0 │ multi_head_atten… │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, None, 256) │        512 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None, 256) │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, None, 30)  │      7,710 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,140,126 (4.35 MB)
#  Trainable params: 1,140,126 (4.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train
checkpoint = ModelCheckpoint(MODEL_PATH, save_best_only=True, monitor='val_loss', verbose=1)

history = model.fit(
    [X_train, dec_in_train],
    np.expand_dims(dec_tgt_train, -1),
    validation_data=([X_test, dec_in_test], np.expand_dims(dec_tgt_test, -1)),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/50
# 2025-12-14 07:50:56.681964: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f1224017a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-14 07:50:56.681983: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-12-14 07:50:56.751327: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-14 07:50:56.950321: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-12-14 07:50:56.950321: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-12-14 07:50:57.181677: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91700
# 2025-12-14 07:50:57.181677: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91700
#  18/358 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5751 - loss: 1.6539
# I0000 00:00:1765698660.368420   99318 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7476 - loss: 0.8284
# 2025-12-14 07:51:03.510661: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7483 - loss: 0.8254
# 2025-12-14 07:51:06.970588: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-12-14 07:51:07.843868: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-12-14 07:51:07.843868: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# Epoch 1: val_loss improved from None to 0.56409, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.7794 - loss: 0.6751 - val_accuracy: 0.8031 - val_loss: 0.5641
# Epoch 2/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.7794 - loss: 0.6751 - val_accuracy: 0.8031 - val_loss: 0.5641
# Epoch 2/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8062 - loss: 0.5517
# Epoch 2: val_loss improved from 0.56409 to 0.50474, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 2: val_loss improved from 0.56409 to 0.50474, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8124 - loss: 0.5325 - val_accuracy: 0.8201 - val_loss: 0.5047
# Epoch 3/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8124 - loss: 0.5325 - val_accuracy: 0.8201 - val_loss: 0.5047
# Epoch 3/50
# 355/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8219 - loss: 0.4991
# Epoch 3: val_loss improved from 0.50474 to 0.48689, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 3: val_loss improved from 0.50474 to 0.48689, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8235 - loss: 0.4963 - val_accuracy: 0.8259 - val_loss: 0.4869
# Epoch 4/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8235 - loss: 0.4963 - val_accuracy: 0.8259 - val_loss: 0.4869
# Epoch 4/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8286 - loss: 0.4812
# Epoch 4: val_loss improved from 0.48689 to 0.47280, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 4: val_loss improved from 0.48689 to 0.47280, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8289 - loss: 0.4791 - val_accuracy: 0.8295 - val_loss: 0.4728
# Epoch 5/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8289 - loss: 0.4791 - val_accuracy: 0.8295 - val_loss: 0.4728
# Epoch 5/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8325 - loss: 0.4693
# Epoch 5: val_loss improved from 0.47280 to 0.46918, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 5: val_loss improved from 0.47280 to 0.46918, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8323 - loss: 0.4700 - val_accuracy: 0.8308 - val_loss: 0.4692
# Epoch 6/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8323 - loss: 0.4700 - val_accuracy: 0.8308 - val_loss: 0.4692
# Epoch 6/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8334 - loss: 0.4657
# Epoch 6: val_loss improved from 0.46918 to 0.46228, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 6: val_loss improved from 0.46918 to 0.46228, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8339 - loss: 0.4639 - val_accuracy: 0.8338 - val_loss: 0.4623
# Epoch 7/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8339 - loss: 0.4639 - val_accuracy: 0.8338 - val_loss: 0.4623
# Epoch 7/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8360 - loss: 0.4573
# Epoch 7: val_loss improved from 0.46228 to 0.46086, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 7: val_loss improved from 0.46228 to 0.46086, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8351 - loss: 0.4599 - val_accuracy: 0.8338 - val_loss: 0.4609
# Epoch 8/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8351 - loss: 0.4599 - val_accuracy: 0.8338 - val_loss: 0.4609
# Epoch 8/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8362 - loss: 0.4563
# Epoch 8: val_loss improved from 0.46086 to 0.45625, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 8: val_loss improved from 0.46086 to 0.45625, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8358 - loss: 0.4565 - val_accuracy: 0.8358 - val_loss: 0.4562
# Epoch 9/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8358 - loss: 0.4565 - val_accuracy: 0.8358 - val_loss: 0.4562
# Epoch 9/50
# 355/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8374 - loss: 0.4512
# Epoch 9: val_loss did not improve from 0.45625
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8367 - loss: 0.4538 - val_accuracy: 0.8359 - val_loss: 0.4571
# Epoch 10/50
#
# Epoch 9: val_loss did not improve from 0.45625
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8367 - loss: 0.4538 - val_accuracy: 0.8359 - val_loss: 0.4571
# Epoch 10/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8376 - loss: 0.4518
# Epoch 10: val_loss improved from 0.45625 to 0.45189, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 10: val_loss improved from 0.45625 to 0.45189, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8372 - loss: 0.4521 - val_accuracy: 0.8362 - val_loss: 0.4519
# Epoch 11/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8372 - loss: 0.4521 - val_accuracy: 0.8362 - val_loss: 0.4519
# Epoch 11/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8384 - loss: 0.4484
# Epoch 11: val_loss did not improve from 0.45189
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8380 - loss: 0.4493 - val_accuracy: 0.8357 - val_loss: 0.4529
# Epoch 12/50
#
# Epoch 11: val_loss did not improve from 0.45189
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8380 - loss: 0.4493 - val_accuracy: 0.8357 - val_loss: 0.4529
# Epoch 12/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8378 - loss: 0.4487
# Epoch 12: val_loss did not improve from 0.45189
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8379 - loss: 0.4485 - val_accuracy: 0.8366 - val_loss: 0.4523
# Epoch 13/50
#
# Epoch 12: val_loss did not improve from 0.45189
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8379 - loss: 0.4485 - val_accuracy: 0.8366 - val_loss: 0.4523
# Epoch 13/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8385 - loss: 0.4467
# Epoch 13: val_loss improved from 0.45189 to 0.44831, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 13: val_loss improved from 0.45189 to 0.44831, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8386 - loss: 0.4462 - val_accuracy: 0.8372 - val_loss: 0.4483
# Epoch 14/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8386 - loss: 0.4462 - val_accuracy: 0.8372 - val_loss: 0.4483
# Epoch 14/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8388 - loss: 0.4448
# Epoch 14: val_loss did not improve from 0.44831
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8391 - loss: 0.4444 - val_accuracy: 0.8369 - val_loss: 0.4487
# Epoch 15/50
#
# Epoch 14: val_loss did not improve from 0.44831
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8391 - loss: 0.4444 - val_accuracy: 0.8369 - val_loss: 0.4487
# Epoch 15/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8400 - loss: 0.4426
# Epoch 15: val_loss improved from 0.44831 to 0.44518, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 15: val_loss improved from 0.44831 to 0.44518, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8396 - loss: 0.4432 - val_accuracy: 0.8379 - val_loss: 0.4452
# Epoch 16/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8396 - loss: 0.4432 - val_accuracy: 0.8379 - val_loss: 0.4452
# Epoch 16/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8407 - loss: 0.4403
# Epoch 16: val_loss did not improve from 0.44518
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8398 - loss: 0.4421 - val_accuracy: 0.8374 - val_loss: 0.4475
# Epoch 17/50
#
# Epoch 16: val_loss did not improve from 0.44518
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8398 - loss: 0.4421 - val_accuracy: 0.8374 - val_loss: 0.4475
# Epoch 17/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8405 - loss: 0.4402
# Epoch 17: val_loss did not improve from 0.44518
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8401 - loss: 0.4409 - val_accuracy: 0.8376 - val_loss: 0.4452
# Epoch 18/50
#
# Epoch 17: val_loss did not improve from 0.44518
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8401 - loss: 0.4409 - val_accuracy: 0.8376 - val_loss: 0.4452
# Epoch 18/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8405 - loss: 0.4385
# Epoch 18: val_loss did not improve from 0.44518
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8399 - loss: 0.4400 - val_accuracy: 0.8375 - val_loss: 0.4461
# Epoch 19/50
#
# Epoch 18: val_loss did not improve from 0.44518
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8399 - loss: 0.4400 - val_accuracy: 0.8375 - val_loss: 0.4461
# Epoch 19/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8400 - loss: 0.4407
# Epoch 19: val_loss improved from 0.44518 to 0.44325, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 19: val_loss improved from 0.44518 to 0.44325, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8409 - loss: 0.4386 - val_accuracy: 0.8391 - val_loss: 0.4433
# Epoch 20/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8409 - loss: 0.4386 - val_accuracy: 0.8391 - val_loss: 0.4433
# Epoch 20/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8422 - loss: 0.4330
# Epoch 20: val_loss improved from 0.44325 to 0.44290, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 20: val_loss improved from 0.44325 to 0.44290, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8408 - loss: 0.4376 - val_accuracy: 0.8386 - val_loss: 0.4429
# Epoch 21/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8408 - loss: 0.4376 - val_accuracy: 0.8386 - val_loss: 0.4429
# Epoch 21/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8411 - loss: 0.4345
# Epoch 21: val_loss improved from 0.44290 to 0.44097, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
#
# Epoch 21: val_loss improved from 0.44290 to 0.44097, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8406 - loss: 0.4369 - val_accuracy: 0.8399 - val_loss: 0.4410
# Epoch 22/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8406 - loss: 0.4369 - val_accuracy: 0.8399 - val_loss: 0.4410
# Epoch 22/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8422 - loss: 0.4340
# Epoch 22: val_loss did not improve from 0.44097
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8414 - loss: 0.4360 - val_accuracy: 0.8389 - val_loss: 0.4427
# Epoch 23/50
#
# Epoch 22: val_loss did not improve from 0.44097
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8414 - loss: 0.4360 - val_accuracy: 0.8389 - val_loss: 0.4427
# Epoch 23/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8412 - loss: 0.4358
# Epoch 23: val_loss improved from 0.44097 to 0.43870, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8417 - loss: 0.4349 - val_accuracy: 0.8404 - val_loss: 0.4387
# Epoch 24/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8420 - loss: 0.4327
# Epoch 24: val_loss did not improve from 0.43870
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8415 - loss: 0.4345 - val_accuracy: 0.8386 - val_loss: 0.4400
# Epoch 25/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8418 - loss: 0.4328
# Epoch 25: val_loss did not improve from 0.43870
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8417 - loss: 0.4338 - val_accuracy: 0.8391 - val_loss: 0.4406
# Epoch 26/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8421 - loss: 0.4330
# Epoch 26: val_loss did not improve from 0.43870
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8422 - loss: 0.4330 - val_accuracy: 0.8375 - val_loss: 0.4431
# Epoch 27/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8422 - loss: 0.4318
# Epoch 27: val_loss improved from 0.43870 to 0.43836, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8424 - loss: 0.4320 - val_accuracy: 0.8394 - val_loss: 0.4384
# Epoch 28/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8419 - loss: 0.4333
# Epoch 28: val_loss did not improve from 0.43836
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8426 - loss: 0.4317 - val_accuracy: 0.8392 - val_loss: 0.4404
# Epoch 29/50
# 353/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8428 - loss: 0.4305
# Epoch 29: val_loss improved from 0.43836 to 0.43746, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8427 - loss: 0.4313 - val_accuracy: 0.8403 - val_loss: 0.4375
# Epoch 30/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8426 - loss: 0.4306
# Epoch 30: val_loss improved from 0.43746 to 0.43566, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8429 - loss: 0.4301 - val_accuracy: 0.8407 - val_loss: 0.4357
# Epoch 31/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8438 - loss: 0.4277
# Epoch 31: val_loss improved from 0.43566 to 0.43521, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8429 - loss: 0.4300 - val_accuracy: 0.8408 - val_loss: 0.4352
# Epoch 32/50
# 351/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8431 - loss: 0.4287
# Epoch 32: val_loss did not improve from 0.43521
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8429 - loss: 0.4292 - val_accuracy: 0.8406 - val_loss: 0.4362
# Epoch 33/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8435 - loss: 0.4277
# Epoch 33: val_loss improved from 0.43521 to 0.43502, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8432 - loss: 0.4287 - val_accuracy: 0.8407 - val_loss: 0.4350
# Epoch 34/50
# 355/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8441 - loss: 0.4269
# Epoch 34: val_loss improved from 0.43502 to 0.43396, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8433 - loss: 0.4292 - val_accuracy: 0.8407 - val_loss: 0.4340
# Epoch 35/50
# 353/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8428 - loss: 0.4281
# Epoch 35: val_loss did not improve from 0.43396
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8435 - loss: 0.4276 - val_accuracy: 0.8416 - val_loss: 0.4343
# Epoch 36/50
# 353/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8445 - loss: 0.4242
# Epoch 36: val_loss did not improve from 0.43396
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8436 - loss: 0.4272 - val_accuracy: 0.8411 - val_loss: 0.4351
# Epoch 37/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8440 - loss: 0.4258
# Epoch 37: val_loss did not improve from 0.43396
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8439 - loss: 0.4265 - val_accuracy: 0.8407 - val_loss: 0.4358
# Epoch 38/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8438 - loss: 0.4259
# Epoch 38: val_loss improved from 0.43396 to 0.43361, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8438 - loss: 0.4264 - val_accuracy: 0.8418 - val_loss: 0.4336
# Epoch 39/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8443 - loss: 0.4257
# Epoch 39: val_loss improved from 0.43361 to 0.43192, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8440 - loss: 0.4260 - val_accuracy: 0.8418 - val_loss: 0.4319
# Epoch 40/50
# 356/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8433 - loss: 0.4266
# Epoch 40: val_loss did not improve from 0.43192
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8444 - loss: 0.4251 - val_accuracy: 0.8416 - val_loss: 0.4320
# Epoch 41/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8439 - loss: 0.4270
# Epoch 41: val_loss did not improve from 0.43192
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8445 - loss: 0.4250 - val_accuracy: 0.8417 - val_loss: 0.4340
# Epoch 42/50
# 355/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8452 - loss: 0.4234
# Epoch 42: val_loss improved from 0.43192 to 0.43182, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8446 - loss: 0.4248 - val_accuracy: 0.8418 - val_loss: 0.4318
# Epoch 43/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8448 - loss: 0.4236
# Epoch 43: val_loss did not improve from 0.43182
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8446 - loss: 0.4244 - val_accuracy: 0.8409 - val_loss: 0.4347
# Epoch 44/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8453 - loss: 0.4232
# Epoch 44: val_loss did not improve from 0.43182
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8447 - loss: 0.4242 - val_accuracy: 0.8412 - val_loss: 0.4324
# Epoch 45/50
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8446 - loss: 0.4244
# Epoch 45: val_loss did not improve from 0.43182
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8447 - loss: 0.4238 - val_accuracy: 0.8408 - val_loss: 0.4334
# Epoch 46/50
# 353/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8442 - loss: 0.4248
# Epoch 46: val_loss improved from 0.43182 to 0.43088, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8451 - loss: 0.4230 - val_accuracy: 0.8421 - val_loss: 0.4309
# Epoch 47/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8441 - loss: 0.4258
# Epoch 47: val_loss did not improve from 0.43088
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8454 - loss: 0.4227 - val_accuracy: 0.8397 - val_loss: 0.4332
# Epoch 48/50
# 354/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8444 - loss: 0.4243
# Epoch 48: val_loss improved from 0.43088 to 0.42847, saving model to /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8454 - loss: 0.4227 - val_accuracy: 0.8429 - val_loss: 0.4285
# Epoch 49/50
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8458 - loss: 0.4207
# Epoch 49: val_loss did not improve from 0.42847
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8452 - loss: 0.4224 - val_accuracy: 0.8429 - val_loss: 0.4293
# Epoch 50/50
# 355/358 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8459 - loss: 0.4200
# Epoch 50: val_loss did not improve from 0.42847
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8452 - loss: 0.4221 - val_accuracy: 0.8425 - val_loss: 0.4302

# %%
# save assets
assets = {
    "khm_tokenizer": khm_tokenizer,
    "eng_tokenizer": eng_tokenizer,
    "max_khm_len": max_khm_len,
    "max_eng_len": max_eng_len
}

with open(ASSETS_PATH, "wb") as file:
    pickle.dump(assets, file)

print(f"Model saved to: {MODEL_PATH}")
print(f"Assets saved to: {ASSETS_PATH}")
# Out:
# Model saved to: /teamspace/studios/this_studio/khm_romanization/models/transformer_romanizer.keras
# Assets saved to: /teamspace/studios/this_studio/khm_romanization/data/processed/transformer_romanization_assets.pkl

# %%
# plot training curves
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Transformer Seq2Seq Loss (Khmer->English)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Transformer Seq2Seq Accuracy (Khmer->English)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_PATH, 'transformer_training_curves.png'))
plt.show()

# %%
# load model and assets for testing
with open(ASSETS_PATH, "rb") as file:
    assets = pickle.load(file)

khm_tokenizer = assets["khm_tokenizer"]
eng_tokenizer = assets["eng_tokenizer"]
max_khm_len = assets["max_khm_len"]
max_eng_len = assets["max_eng_len"]

model = tf.keras.models.load_model(MODEL_PATH)
print("Model and assets loaded successfully")


def romanize(khmer_text):
    """
    Romanize Khmer text to English using the trained transformer model.
    
    Args:
        khmer_text: Input Khmer text string
        
    Returns:
        Romanized English text
    """
    # clean input
    khmer_text = str(khmer_text).strip()
    khmer_text = re.sub(r"[^\u1780-\u17FF]", "", khmer_text)
    khmer_text = unicodedata.normalize('NFC', khmer_text)
    
    if not khmer_text:
        return ""
    
    # encode input
    khm_seq = khm_tokenizer.texts_to_sequences([khmer_text])
    encoder_input = pad_sequences(khm_seq, maxlen=max_khm_len, padding='post')
    
    # initialize decoder input with start token
    decoder_input = np.zeros((1, max_eng_len + 1), dtype=np.int32)
    decoder_input[0, 0] = eng_tokenizer.word_index['\t']
    
    # decode character by character
    decoded_chars = []
    
    for i in range(max_eng_len):
        # predict next character
        predictions = model.predict([encoder_input, decoder_input], verbose=0)
        
        # get the character at current position
        char_index = np.argmax(predictions[0, i, :])
        
        # convert index to character
        if char_index == 0:
            # padding token, skip
            break
        
        char = eng_tokenizer.index_word.get(char_index, '')
        
        # stop if end token
        if char == '\n':
            break
        
        # skip special tokens in output
        if char not in ['\t', '<unk>']:
            decoded_chars.append(char)
        
        # update decoder input for next position
        if i + 1 < max_eng_len + 1:
            decoder_input[0, i + 1] = char_index
    
    return ''.join(decoded_chars)
# Out:
# Model and assets loaded successfully

# %%
romanize("សួ")
# Out:
# 's'

# %%
romanize("ក្ដា")
# Out:
# 'kda'

# %%
romanize("ក្ដី")
# Out:
# 'kdei'

# %%
romanize("ពួក")
# Out:
# 'puouououououououououououo'
